# %% [markdown]
# ## Reading the CSV File and Displaying the Dataframe

# %%
# importing pandas library
import pandas as pd

# Giving the path of the CSV file and stored in a variable name file
file = "C:\\Users\\himav\\OneDrive\\Desktop\\4. Text Based Analysis\\TBA Assignment\\TopAnimatedImDb.csv"

# Reading the CSV file and stored in a variable named called dataframe(df)
df = pd.read_csv(file)

# Printing the first 20 rows of the data from the CSV file
df.head(20)
# Out:
#                                  Title  Rating      Votes     Gross  \
# 0        Sen to Chihiro no kamikakushi     8.6    747,148   $10.06M
# 1                        The Lion King     8.5  1,041,158  $422.78M
# 2                       Hotaru no haka     8.5    272,469       NaN
# 3                       Kimi no na wa.     8.4    259,975    $5.02M
# 4    Spider-Man: Into the Spider-Verse     8.4    510,227  $190.24M
# 5                                 Coco     8.4    492,081  $209.73M
# 6                               WALL·E     8.4  1,100,175  $223.81M
# 7                        Mononoke-hime     8.4    388,925    $2.38M
# 8                                   Up     8.3  1,029,395  $293.00M
# 9                          Toy Story 3     8.3    826,193  $415.00M
# 10                           Toy Story     8.3    979,994  $191.80M
# 11                          Inside Out     8.2    701,106  $356.46M
# 12  Kimetsu no Yaiba: Mugen Ressha-Hen     8.2     55,255       NaN
# 13                Hauru no ugoku shiro     8.2    387,977    $4.71M
# 14                        Finding Nemo     8.2  1,031,038  $380.84M
# 15                      Koe no katachi     8.1     78,876       NaN
# 16                               Klaus     8.1    146,042       NaN
# 17         Ôkami kodomo no Ame to Yuki     8.1     44,668       NaN
# 18                       Mary and Max.     8.1    176,615       NaN
# 19            How to Train Your Dragon     8.1    730,922  $217.58M
#
#                   Genre  Metascore Certificate         Director  Year  \
# 0     Adventure, Family       96.0           U   Hayao Miyazaki  2001
# 1      Adventure, Drama       88.0           U     Roger Allers  1994
# 2            Drama, War       94.0           U    Isao Takahata  1988
# 3        Drama, Fantasy       79.0           U   Makoto Shinkai  2016
# 4     Action, Adventure       87.0           U  Bob Persichetti  2018
# 5     Adventure, Comedy       81.0           U      Lee Unkrich  2017
# 6     Adventure, Family       95.0           U   Andrew Stanton  2008
# 7    Adventure, Fantasy       76.0           U   Hayao Miyazaki  1997
# 8     Adventure, Comedy       88.0           U      Pete Docter  2009
# 9     Adventure, Comedy       92.0           U      Lee Unkrich  2010
# 10    Adventure, Comedy       95.0           U    John Lasseter  1995
# 11    Adventure, Comedy       94.0           U      Pete Docter  2015
# 12    Action, Adventure       72.0          UA   Haruo Sotozaki  2020
# 13    Adventure, Family       80.0           U   Hayao Miyazaki  2004
# 14    Adventure, Comedy       90.0           U   Andrew Stanton  2003
# 15                Drama       78.0          16     Naoko Yamada  2016
# 16    Adventure, Comedy       65.0           7    Sergio Pablos  2019
# 17        Drama, Family       71.0           U    Mamoru Hosoda  2012
# 18        Comedy, Drama        NaN         NaN      Adam Elliot  2009
# 19    Action, Adventure       75.0           U     Dean DeBlois  2010
#
#                                           Description  Runtime
# 0   ["\nDuring her family's move to the suburbs, a...  125 min
# 1   ['\nLion prince Simba and his father are targe...   88 min
# 2   ['\nA young boy and his little sister struggle...   89 min
# 3   ['\nTwo strangers find themselves linked in a ...  106 min
# 4   ['\nTeen Miles Morales becomes the Spider-Man ...  117 min
# 5   ["\nAspiring musician Miguel, confronted with ...  105 min
# 6   ['\nIn the distant future, a small waste-colle...   98 min
# 7   ["\nOn a journey to find the cure for a Tatari...  134 min
# 8   ['\n78-year-old Carl Fredricksen travels to Pa...   96 min
# 9   ["\nThe toys are mistakenly delivered to a day...  103 min
# 10  ["\nA cowboy doll is profoundly threatened and...   81 min
# 11  ['\nAfter young Riley is uprooted from her Mid...   95 min
# 12  ["\nAfter his family was brutally murdered and...  117 min
# 13  ['\nWhen an unconfident young woman is cursed ...  119 min
# 14  ['\nAfter his son is captured in the Great Bar...  100 min
# 15  ['\nA young man is ostracized by his classmate...  130 min
# 16  ["\nA simple act of kindness always sparks ano...   96 min
# 17  ['\nAfter her werewolf lover unexpectedly dies...  117 min
# 18  ['\nA tale of friendship between two unlikely ...   92 min
# 19  ['\nA hapless young Viking who aspires to hunt...   98 min

# %% [markdown]
# ## Remove Stop words

# %%
# We will use the list of English stop words that are standard in python
import nltk
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'there', 'yours', 'this', 'as', 'weren', 'which', 'do', "needn't", 'she', 'so', 'doesn', "you'll", 'each', 'the', "that'll", 'himself', 'has', 'further', 'are', 'and', 'themselves', 'its', 't', 'won', 'now', 'too', 'up', "didn't", 'they', 'that', 'my', 'isn', "hadn't", "you've", 'while', 'at', 'didn', 'am', 'wasn', 'once', 'both', 'is', "couldn't", 'these', 'by', 'itself', 'above', 'those', 'during', 'will', 'him', 'or', 'their', 'couldn', "shouldn't", 'of', 'about', 'any', 'our', 'more', 'no', 'y', 'who', 'does', 'between', 's', "aren't", 'against', 'here', 'ours', 'yourself', 'be', 'haven', 'down', 'wouldn', 'don', 'should', 'into', 'what', 'all', 'needn', 'can', 'whom', 'theirs', 'then', 'few', 'hadn', 'other', "isn't", 'ma', 'most', 'being', 'her', 'o', 'an', 'them', "should've", 'where', 'doing', 'yourselves', "haven't", 'aren', 'out', 'below', 'me', 'again', 'same', 'have', 'was', 'if', 'having', 'through', "doesn't", 'because', "wasn't", 'shan', 'm', 'after', 'until', 'why', 'mustn', "wouldn't", 'just', 'you', 'off', "won't", 'he', 'd', "you'd", "don't", 'i', 'to', 'nor', "she's", 'when', 'been', 'such', 've', 'but', 'your', 'only', 'very', 'a', 'how', 'did', 'll', 'hasn', 'had', 'his', 'hers', 'it', 'from', 'than', 'for', 'over', 'some', 'myself', 'herself', 'before', "weren't", 'shouldn', 'ain', 'on', 'with', 'under', 're', "hasn't", "mustn't", 'own', 'not', "you're", 'mightn', 'we', "mightn't", 'in', "shan't", "it's", 'ourselves', 'were'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\himav\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Function to tokenize

# %%
# Tokenizing a Function using a function tokenize()
import regex as re

def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# %% [markdown]
# ## Function to remove stop words

# %%
# Removing the stop words using a function remove_stop()
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

# %% [markdown]
# ## Let's make a Pipeline

# %%
# Making a Pipeline
pipeline = [str.lower, tokenize, remove_stop]
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %% [markdown]
# ## Run the Pipeline

# %%
# Running a pipeline
df['tokens'] = df['Description'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# ## Put the word frequency in it's own dataframe for analysis

# %%
# put the word frequency in it’s own dataframe for analysis
from collections import Counter
counter = Counter()
df['tokens'].map(counter.update)
freq_df = pd.DataFrame.from_dict(counter, orient='index',columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %% [markdown]
# ## Sort and display!

# %%
# Sorting and Displaying 10 values of the frequency dataframe
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#         freq
# token
# na        34
# young     25
# girl      15
# world     13
# boy       12
# new       12
# must       9
# nwhen      9
# family     8
# find       7

# %% [markdown]
# ## All Data wordcloud

# %%
# Printing output with the needy requirements
from wordcloud import WordCloud
from matplotlib import pyplot as plt
wc = WordCloud(background_color='white', width = 300, height=300, margin=2)
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %% [markdown]
# ## Do the TFIDF and do the Comparision

# %%
# Do the TFIDF and do the Comparision
import numpy as np
def compute_idf(df, column='tokens', preprocess=None, min_df=1):
    def update(doc):
            tokens = doc if preprocess is None else preprocess(doc)
            counter.update(set(tokens))
            
    # count tokens
    counter = Counter()
    df[column].map(update)
    
    # create data frame and compute idf
    idf_df = pd.DataFrame.from_dict(counter, orient='index', columns=['df'])
    idf_df = idf_df.query('df >= @min_df')
    idf_df['idf'] = np.log(len(df)/idf_df['df'])+0.1
    idf_df.index.name = 'token'
    return idf_df
idf_df = compute_idf(df)

# %%
# Describing the data of the frequency dataframe
freq_df['tfidf'] = freq_df['freq'] * idf_df['idf']
freq_df.head()
# Out:
#        freq      tfidf
# token
# na       34  34.553885
# young    25  36.290220
# girl     15  28.553909
# world    13  27.881828
# boy      12  24.692935

# %% [markdown]
# ## Wordcloud

# %%
# Printing output with the needy requirements
wc = WordCloud(background_color='white', width = 300, height=300,margin=2)
wc.fit_words(freq_df['tfidf'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
# And also we can try other years or countries for fun to see the comparision between the TF and TFIDF
# import pandas as pd
# file = “ "
# df = pd.read_csv(file)
# df= df[df['year']==2001]
# df.head(20)

# %% [markdown]
# ## Function to count the keywords

# %%
# Function to count the keywords
df['num_tokens'] = df['tokens'].map(len)
def count_keywords(tokens, keywords):
    tokens = [t for t in tokens if t in keywords]
    counter = Counter(tokens)
    return [counter.get(k, 0) for k in keywords]

# %% [markdown]
# ## Function to groupby year

# %%
# Function to groupby year
def count_keywords_by(df, by, keywords, column='tokens'):
    df = df.reset_index(drop=True) # if the supplied dataframe has gaps inthe index
    freq_matrix = df[column].apply(count_keywords, keywords=keywords)
    freq_df = pd.DataFrame.from_records(freq_matrix,columns=keywords)
    freq_df[by] = df[by] # copy the grouping column(s)
    
    return freq_df.groupby(by=by).sum().sort_values(by)

# %% [markdown]
# ## Finalizing the Heatmap

# %%
# Finalizing the Heatmap
import seaborn as sns
keywords = ['study', 'exam', 'subject', 'class','time', 'friends', 'games', 'love', 'teacher','fun', 'memories', 'birthday','english', 'period','lecture']
freq_df = count_keywords_by(df, by='Runtime', keywords=keywords)

# compute relative frequencies based on total number of tokens per year
freq_df = freq_df.div(df.groupby('Runtime')['num_tokens'].sum(), axis=0)

# apply square root as sublinear filter for better contrast
freq_df = freq_df.apply(np.sqrt)
plt.figure(figsize=(15, 7))
sns.set(font_scale=1)
sns.heatmap(data=freq_df.T,xticklabels=True, yticklabels=True, cbar=False, cmap="Reds")
sns.set(font_scale=1)
