# %% [markdown]
# ## Reading the CSV File and Displaying the DataFrame!

# %%
# importing pandas library
import pandas as pd

# Giving the path of the CSV file and stored in a variable name file
file = "C:\\Users\\himav\\OneDrive\\Desktop\\TopAnimatedImDb.csv"

# Reading the CSV file and stored in a variable named called dataframe(df)
df = pd.read_csv(file)

# Printing the first 20 rows of the data from the CSV file
df.head(20)
# Out:
#                                  Title  Rating      Votes     Gross  \
# 0        Sen to Chihiro no kamikakushi     8.6    747,148   $10.06M
# 1                        The Lion King     8.5  1,041,158  $422.78M
# 2                       Hotaru no haka     8.5    272,469       NaN
# 3                       Kimi no na wa.     8.4    259,975    $5.02M
# 4    Spider-Man: Into the Spider-Verse     8.4    510,227  $190.24M
# 5                                 Coco     8.4    492,081  $209.73M
# 6                               WALL·E     8.4  1,100,175  $223.81M
# 7                        Mononoke-hime     8.4    388,925    $2.38M
# 8                                   Up     8.3  1,029,395  $293.00M
# 9                          Toy Story 3     8.3    826,193  $415.00M
# 10                           Toy Story     8.3    979,994  $191.80M
# 11                          Inside Out     8.2    701,106  $356.46M
# 12  Kimetsu no Yaiba: Mugen Ressha-Hen     8.2     55,255       NaN
# 13                Hauru no ugoku shiro     8.2    387,977    $4.71M
# 14                        Finding Nemo     8.2  1,031,038  $380.84M
# 15                      Koe no katachi     8.1     78,876       NaN
# 16                               Klaus     8.1    146,042       NaN
# 17         Ôkami kodomo no Ame to Yuki     8.1     44,668       NaN
# 18                       Mary and Max.     8.1    176,615       NaN
# 19            How to Train Your Dragon     8.1    730,922  $217.58M
#
#                   Genre  Metascore Certificate         Director  Year  \
# 0     Adventure, Family       96.0           U   Hayao Miyazaki  2001
# 1      Adventure, Drama       88.0           U     Roger Allers  1994
# 2            Drama, War       94.0           U    Isao Takahata  1988
# 3        Drama, Fantasy       79.0           U   Makoto Shinkai  2016
# 4     Action, Adventure       87.0           U  Bob Persichetti  2018
# 5     Adventure, Comedy       81.0           U      Lee Unkrich  2017
# 6     Adventure, Family       95.0           U   Andrew Stanton  2008
# 7    Adventure, Fantasy       76.0           U   Hayao Miyazaki  1997
# 8     Adventure, Comedy       88.0           U      Pete Docter  2009
# 9     Adventure, Comedy       92.0           U      Lee Unkrich  2010
# 10    Adventure, Comedy       95.0           U    John Lasseter  1995
# 11    Adventure, Comedy       94.0           U      Pete Docter  2015
# 12    Action, Adventure       72.0          UA   Haruo Sotozaki  2020
# 13    Adventure, Family       80.0           U   Hayao Miyazaki  2004
# 14    Adventure, Comedy       90.0           U   Andrew Stanton  2003
# 15                Drama       78.0          16     Naoko Yamada  2016
# 16    Adventure, Comedy       65.0           7    Sergio Pablos  2019
# 17        Drama, Family       71.0           U    Mamoru Hosoda  2012
# 18        Comedy, Drama        NaN         NaN      Adam Elliot  2009
# 19    Action, Adventure       75.0           U     Dean DeBlois  2010
#
#                                           Description  Runtime
# 0   ["\nDuring her family's move to the suburbs, a...  125 min
# 1   ['\nLion prince Simba and his father are targe...   88 min
# 2   ['\nA young boy and his little sister struggle...   89 min
# 3   ['\nTwo strangers find themselves linked in a ...  106 min
# 4   ['\nTeen Miles Morales becomes the Spider-Man ...  117 min
# 5   ["\nAspiring musician Miguel, confronted with ...  105 min
# 6   ['\nIn the distant future, a small waste-colle...   98 min
# 7   ["\nOn a journey to find the cure for a Tatari...  134 min
# 8   ['\n78-year-old Carl Fredricksen travels to Pa...   96 min
# 9   ["\nThe toys are mistakenly delivered to a day...  103 min
# 10  ["\nA cowboy doll is profoundly threatened and...   81 min
# 11  ['\nAfter young Riley is uprooted from her Mid...   95 min
# 12  ["\nAfter his family was brutally murdered and...  117 min
# 13  ['\nWhen an unconfident young woman is cursed ...  119 min
# 14  ['\nAfter his son is captured in the Great Bar...  100 min
# 15  ['\nA young man is ostracized by his classmate...  130 min
# 16  ["\nA simple act of kindness always sparks ano...   96 min
# 17  ['\nAfter her werewolf lover unexpectedly dies...  117 min
# 18  ['\nA tale of friendship between two unlikely ...   92 min
# 19  ['\nA hapless young Viking who aspires to hunt...   98 min

# %% [markdown]
# ## Columns

# %%
# Prinitng the column names for an overview
df.columns
# Out:
# Index(['Title', 'Rating', 'Votes', 'Gross', 'Genre', 'Metascore',
#        'Certificate', 'Director', 'Year', 'Description', 'Runtime'],
#       dtype='object')

# %% [markdown]
# ## dtypes

# %%
# Printing the data types of the columns
df.dtypes
# Out:
# Title           object
# Rating         float64
# Votes           object
# Gross           object
# Genre           object
# Metascore      float64
# Certificate     object
# Director        object
# Year             int64
# Description     object
# Runtime         object
# dtype: object

# %% [markdown]
# ## info()

# %%
# Printing the information for an overview
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        85 non-null     object
#  1   Rating       85 non-null     float64
#  2   Votes        85 non-null     object
#  3   Gross        50 non-null     object
#  4   Genre        85 non-null     object
#  5   Metascore    80 non-null     float64
#  6   Certificate  84 non-null     object
#  7   Director     85 non-null     object
#  8   Year         85 non-null     int64
#  9   Description  85 non-null     object
#  10  Runtime      85 non-null     object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 7.4+ KB

# %% [markdown]
# ## describe()

# %%
# Describing the data of the CSV File
df.describe()
# Out:
#           Rating  Metascore         Year
# count  85.000000  80.000000    85.000000
# mean    7.922353  80.850000  2003.211765
# std     0.257449   8.965616    15.255830
# min     7.600000  59.000000  1937.000000
# 25%     7.700000  74.000000  1995.000000
# 50%     7.900000  82.000000  2007.000000
# 75%     8.100000  87.000000  2014.000000
# max     8.600000  96.000000  2021.000000

# %% [markdown]
# ## New column with the Length of the "Description" Column

# %%
# Adding a new column with the length of the “Description” column
df['length'] = df['Description'].str.len()

# Describing the output
df.describe()
# Out:
#           Rating  Metascore         Year      length
# count  85.000000  80.000000    85.000000   85.000000
# mean    7.922353  80.850000  2003.211765  161.070588
# std     0.257449   8.965616    15.255830   44.194588
# min     7.600000  59.000000  1937.000000   81.000000
# 25%     7.700000  74.000000  1995.000000  135.000000
# 50%     7.900000  82.000000  2007.000000  149.000000
# 75%     8.100000  87.000000  2014.000000  204.000000
# max     8.600000  96.000000  2021.000000  274.000000

# %% [markdown]
# ## Text Field

# %%
# Using the Describe method
df.describe(include='O')
# Out:
#                                 Title    Votes   Gross               Genre  \
# count                              85       85      50                  85
# unique                             85       85      49                  20
# top     Sen to Chihiro no kamikakushi  747,148  $0.19M   Adventure, Comedy
# freq                                1        1       2                  30
#
#        Certificate        Director  \
# count           84              85
# unique          10              55
# top              U  Hayao Miyazaki
# freq            60              10
#
#                                               Description  Runtime
# count                                                  85       85
# unique                                                 85       41
# top     ["\nDuring her family's move to the suburbs, a...  100 min
# freq                                                    1        7

# %% [markdown]
# ## Check for Missing Data

# %%
# Checking for missing data
df.isna().sum()
# Out:
# Title           0
# Rating          0
# Votes           0
# Gross          35
# Genre           0
# Metascore       5
# Certificate     1
# Director        0
# Year            0
# Description     0
# Runtime         0
# length          0
# dtype: int64

# %% [markdown]
# ## Fill the Missing Data

# %%
# Filling the missing data in the column Director
df['Director'].fillna('unknown', inplace=True)

#Filling the missing data in the column Description
df['Description'].fillna('unknown', inplace=True)
df.isna().sum()
# Out:
# Title           0
# Rating          0
# Votes           0
# Gross          35
# Genre           0
# Metascore       5
# Certificate     1
# Director        0
# Year            0
# Description     0
# Runtime         0
# length          0
# dtype: int64

# %% [markdown]
# ## Uppercase (or Lowercase) 'Genre' Column

# %%
# Converting and printing the Genre column data into uppercase using upper() method
df['Genre'] = df['Genre'].str.upper()
df
# Out:
#                                 Title  Rating      Votes     Gross  \
# 0       Sen to Chihiro no kamikakushi     8.6    747,148   $10.06M
# 1                       The Lion King     8.5  1,041,158  $422.78M
# 2                      Hotaru no haka     8.5    272,469       NaN
# 3                      Kimi no na wa.     8.4    259,975    $5.02M
# 4   Spider-Man: Into the Spider-Verse     8.4    510,227  $190.24M
# ..                                ...     ...        ...       ...
# 80                      Kung Fu Panda     7.6    463,897  $215.43M
# 81                              Mulan     7.6    284,542  $120.62M
# 82                 The Little Mermaid     7.6    260,026  $111.54M
# 83                    The Jungle Book     7.6    181,528  $141.84M
# 84    Snow White and the Seven Dwarfs     7.6    197,860  $184.93M
#
#                  Genre  Metascore Certificate             Director  Year  \
# 0    ADVENTURE, FAMILY       96.0           U       Hayao Miyazaki  2001
# 1     ADVENTURE, DRAMA       88.0           U         Roger Allers  1994
# 2           DRAMA, WAR       94.0           U        Isao Takahata  1988
# 3       DRAMA, FANTASY       79.0           U       Makoto Shinkai  2016
# 4    ACTION, ADVENTURE       87.0           U      Bob Persichetti  2018
# ..                 ...        ...         ...                  ...   ...
# 80   ACTION, ADVENTURE       74.0           U         Mark Osborne  2008
# 81   ADVENTURE, COMEDY       71.0           U        Tony Bancroft  1998
# 82   ADVENTURE, COMEDY       88.0           U         Ron Clements  1989
# 83   ADVENTURE, COMEDY       65.0           U  Wolfgang Reitherman  1967
# 84   ADVENTURE, FAMILY       95.0           U     William Cottrell  1937
#
#                                           Description  Runtime  length
# 0   ["\nDuring her family's move to the suburbs, a...  125 min     172
# 1   ['\nLion prince Simba and his father are targe...   88 min     112
# 2   ['\nA young boy and his little sister struggle...   89 min      89
# 3   ['\nTwo strangers find themselves linked in a ...  106 min     137
# 4   ['\nTeen Miles Morales becomes the Spider-Man ...  117 min     173
# ..                                                ...      ...     ...
# 80  ["\nTo everyone's surprise, including his own,...   92 min     206
# 81  ["\nTo save her father from death in the army,...   88 min     151
# 82  ["\nA mermaid princess makes a Faustian bargai...   83 min     104
# 83  ['\nBagheera the Panther and Baloo the Bear ha...   78 min     136
# 84  ['\nExiled into the dangerous forest by her wi...   83 min     146
#
# [85 rows x 12 columns]

# %% [markdown]
# ## Uppercase (or Lowercase) 'Director' Column

# %%
# Converting and printing the Director column data into uppercase using upper() method
df['Director'] = df['Director'].str.upper()
df
# Out:
#                                 Title  Rating      Votes     Gross  \
# 0       Sen to Chihiro no kamikakushi     8.6    747,148   $10.06M
# 1                       The Lion King     8.5  1,041,158  $422.78M
# 2                      Hotaru no haka     8.5    272,469       NaN
# 3                      Kimi no na wa.     8.4    259,975    $5.02M
# 4   Spider-Man: Into the Spider-Verse     8.4    510,227  $190.24M
# ..                                ...     ...        ...       ...
# 80                      Kung Fu Panda     7.6    463,897  $215.43M
# 81                              Mulan     7.6    284,542  $120.62M
# 82                 The Little Mermaid     7.6    260,026  $111.54M
# 83                    The Jungle Book     7.6    181,528  $141.84M
# 84    Snow White and the Seven Dwarfs     7.6    197,860  $184.93M
#
#                  Genre  Metascore Certificate             Director  Year  \
# 0    ADVENTURE, FAMILY       96.0           U       HAYAO MIYAZAKI  2001
# 1     ADVENTURE, DRAMA       88.0           U         ROGER ALLERS  1994
# 2           DRAMA, WAR       94.0           U        ISAO TAKAHATA  1988
# 3       DRAMA, FANTASY       79.0           U       MAKOTO SHINKAI  2016
# 4    ACTION, ADVENTURE       87.0           U      BOB PERSICHETTI  2018
# ..                 ...        ...         ...                  ...   ...
# 80   ACTION, ADVENTURE       74.0           U         MARK OSBORNE  2008
# 81   ADVENTURE, COMEDY       71.0           U        TONY BANCROFT  1998
# 82   ADVENTURE, COMEDY       88.0           U         RON CLEMENTS  1989
# 83   ADVENTURE, COMEDY       65.0           U  WOLFGANG REITHERMAN  1967
# 84   ADVENTURE, FAMILY       95.0           U     WILLIAM COTTRELL  1937
#
#                                           Description  Runtime  length
# 0   ["\nDuring her family's move to the suburbs, a...  125 min     172
# 1   ['\nLion prince Simba and his father are targe...   88 min     112
# 2   ['\nA young boy and his little sister struggle...   89 min      89
# 3   ['\nTwo strangers find themselves linked in a ...  106 min     137
# 4   ['\nTeen Miles Morales becomes the Spider-Man ...  117 min     173
# ..                                                ...      ...     ...
# 80  ["\nTo everyone's surprise, including his own,...   92 min     206
# 81  ["\nTo save her father from death in the army,...   88 min     151
# 82  ["\nA mermaid princess makes a Faustian bargai...   83 min     104
# 83  ['\nBagheera the Panther and Baloo the Bear ha...   78 min     136
# 84  ['\nExiled into the dangerous forest by her wi...   83 min     146
#
# [85 rows x 12 columns]

# %% [markdown]
# ## Uppercase (or Lowercase) 'Description' Column

# %%
# Converting and printing the Description column data into uppercase using upper() method
df['Description'] = df['Description'].str.upper()
df
# Out:
#                                 Title  Rating      Votes     Gross  \
# 0       Sen to Chihiro no kamikakushi     8.6    747,148   $10.06M
# 1                       The Lion King     8.5  1,041,158  $422.78M
# 2                      Hotaru no haka     8.5    272,469       NaN
# 3                      Kimi no na wa.     8.4    259,975    $5.02M
# 4   Spider-Man: Into the Spider-Verse     8.4    510,227  $190.24M
# ..                                ...     ...        ...       ...
# 80                      Kung Fu Panda     7.6    463,897  $215.43M
# 81                              Mulan     7.6    284,542  $120.62M
# 82                 The Little Mermaid     7.6    260,026  $111.54M
# 83                    The Jungle Book     7.6    181,528  $141.84M
# 84    Snow White and the Seven Dwarfs     7.6    197,860  $184.93M
#
#                  Genre  Metascore Certificate             Director  Year  \
# 0    ADVENTURE, FAMILY       96.0           U       HAYAO MIYAZAKI  2001
# 1     ADVENTURE, DRAMA       88.0           U         ROGER ALLERS  1994
# 2           DRAMA, WAR       94.0           U        ISAO TAKAHATA  1988
# 3       DRAMA, FANTASY       79.0           U       MAKOTO SHINKAI  2016
# 4    ACTION, ADVENTURE       87.0           U      BOB PERSICHETTI  2018
# ..                 ...        ...         ...                  ...   ...
# 80   ACTION, ADVENTURE       74.0           U         MARK OSBORNE  2008
# 81   ADVENTURE, COMEDY       71.0           U        TONY BANCROFT  1998
# 82   ADVENTURE, COMEDY       88.0           U         RON CLEMENTS  1989
# 83   ADVENTURE, COMEDY       65.0           U  WOLFGANG REITHERMAN  1967
# 84   ADVENTURE, FAMILY       95.0           U     WILLIAM COTTRELL  1937
#
#                                           Description  Runtime  length
# 0   ["\NDURING HER FAMILY'S MOVE TO THE SUBURBS, A...  125 min     172
# 1   ['\NLION PRINCE SIMBA AND HIS FATHER ARE TARGE...   88 min     112
# 2   ['\NA YOUNG BOY AND HIS LITTLE SISTER STRUGGLE...   89 min      89
# 3   ['\NTWO STRANGERS FIND THEMSELVES LINKED IN A ...  106 min     137
# 4   ['\NTEEN MILES MORALES BECOMES THE SPIDER-MAN ...  117 min     173
# ..                                                ...      ...     ...
# 80  ["\NTO EVERYONE'S SURPRISE, INCLUDING HIS OWN,...   92 min     206
# 81  ["\NTO SAVE HER FATHER FROM DEATH IN THE ARMY,...   88 min     151
# 82  ["\NA MERMAID PRINCESS MAKES A FAUSTIAN BARGAI...   83 min     104
# 83  ['\NBAGHEERA THE PANTHER AND BALOO THE BEAR HA...   78 min     136
# 84  ['\NEXILED INTO THE DANGEROUS FOREST BY HER WI...   83 min     146
#
# [85 rows x 12 columns]

# %% [markdown]
# ## Directors with 'HAYAO MIYAZAKI' in them

# %%
# Printing the data contains 'HAYAO MIYAZAKI' in Director column
df[df['Director'].str.contains('HAYAO MIYAZAKI')]
# Out:
#                             Title  Rating    Votes    Gross  \
# 0   Sen to Chihiro no kamikakushi     8.6  747,148  $10.06M
# 7                   Mononoke-hime     8.4  388,925   $2.38M
# 13           Hauru no ugoku shiro     8.2  387,977   $4.71M
# 23               Tonari no Totoro     8.1  333,845   $1.11M
# 36         Tenkû no shiro Rapyuta     8.0  165,250      NaN
# 37       Kaze no tani no Naushika     8.0  168,233      NaN
# 54              Majo no takkyûbin     7.8  143,013      NaN
# 59                   Kaze tachinu     7.7   85,123   $5.21M
# 71                Kurenai no buta     7.7   89,026      NaN
# 79            Gake no ue no Ponyo     7.6  142,408  $15.09M
#
#                   Genre  Metascore Certificate        Director  Year  \
# 0     ADVENTURE, FAMILY       96.0           U  HAYAO MIYAZAKI  2001
# 7    ADVENTURE, FANTASY       76.0           U  HAYAO MIYAZAKI  1997
# 13    ADVENTURE, FAMILY       80.0           U  HAYAO MIYAZAKI  2004
# 23       COMEDY, FAMILY       86.0           U  HAYAO MIYAZAKI  1988
# 36    ADVENTURE, FAMILY       78.0           U  HAYAO MIYAZAKI  1986
# 37    ADVENTURE, SCI-FI       86.0           U  HAYAO MIYAZAKI  1984
# 54    ADVENTURE, FAMILY       83.0           U  HAYAO MIYAZAKI  1989
# 59     BIOGRAPHY, DRAMA       83.0   Not Rated  HAYAO MIYAZAKI  2013
# 71    ADVENTURE, COMEDY       83.0           U  HAYAO MIYAZAKI  1992
# 79    ADVENTURE, COMEDY       86.0           U  HAYAO MIYAZAKI  2008
#
#                                           Description  Runtime  length
# 0   ["\NDURING HER FAMILY'S MOVE TO THE SUBURBS, A...  125 min     172
# 7   ["\NON A JOURNEY TO FIND THE CURE FOR A TATARI...  134 min     212
# 13  ['\NWHEN AN UNCONFIDENT YOUNG WOMAN IS CURSED ...  119 min     226
# 23  ['\NWHEN TWO GIRLS MOVE TO THE COUNTRY TO BE N...   86 min     143
# 36  ['\NA YOUNG BOY AND A GIRL WITH A MAGIC CRYSTA...  125 min     139
# 37  ['\NWARRIOR AND PACIFIST PRINCESS NAUSICAÄ DES...  117 min     148
# 54  ['\NA YOUNG WITCH, ON HER MANDATORY YEAR OF IN...  103 min     170
# 59  ['\NA LOOK AT THE LIFE OF JIRO HORIKOSHI, THE ...  126 min     109
# 71  ['\NIN 1930S ITALY, A VETERAN WORLD WAR I PILO...   94 min      96
# 79  ['\NA FIVE-YEAR-OLD BOY DEVELOPS A RELATIONSHI...  101 min     147

# %% [markdown]
# ## Charts

# %%
# Plotting the Graph
df['length'].plot()
# Out:
# <Axes: >

# %%
# Plotting the length graph in a kind of box in the horizontal position 
df['length'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %% [markdown]
# ## Histogram

# %%
# Plotting the histogram Graph labelling Y-axis as Frequency
df['length'].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Bar Plot

# %%
# Printing the Bar Plot taking X-axis as 'Certificate' and Y-axis as 'Length'
import seaborn as sns
where = df['Certificate'].isin(['U', 'UA'])
g = sns.catplot(data=df[where], x="Certificate", y="length", kind='box')
g.fig.set_size_inches(10, 8) ###
# Out:
# C:\Users\himav\.anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Function to tokenize

# %%
# Tokenizing a Function using a function tokenize()
import regex as re
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

x = tokenize('hima Varshini')
print(x)
# Out:
# ['hima', 'Varshini']

# %% [markdown]
# ## Example

# %%
# Try it out before running it on the whole dataset
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %% [markdown]
# ## Remove stop words

# %%
# We will use the list of English stop words that are standard in python
import nltk
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {"shan't", 'her', 'your', 'myself', 'nor', 'mightn', 'by', 'why', 'hers', 'own', 'where', 'here', 'couldn', "isn't", 'few', 'y', 'on', 'off', 'its', 'hadn', 'he', 'aren', 'no', 'mustn', "should've", 'each', 'can', 'haven', 'won', 'further', 'the', 'o', "mustn't", 'down', "you'd", 'so', "it's", 'while', 'what', 'them', 'under', 'to', "needn't", 'a', "wouldn't", "haven't", 'some', 'have', 'most', 'over', 'before', 'yourself', 'other', 'me', 'ain', 'whom', 'had', 'don', 'wasn', 'when', 'she', 'through', 'as', 'about', "you've", 'it', 'in', 'an', 'having', "don't", 'who', 'from', 'my', 'our', 'herself', 'should', 'too', 'at', "aren't", 'because', 'is', 'themselves', 'out', 'll', "wasn't", "hasn't", 'against', 'doesn', 'his', 'himself', 'for', 've', 'same', 'shan', "you're", 'hasn', 'their', 'after', 'shouldn', 'or', 'doing', 'd', 'am', 'needn', 't', 'm', 'and', 'up', 'above', 'just', "she's", 'into', 'only', 'how', 's', 'you', 'they', 'these', 'all', 'again', 'not', 'once', 'than', 'ma', 'him', 'there', 'such', "mightn't", 'this', 'was', "that'll", "couldn't", 'those', "didn't", 'ourselves', 'do', 'of', 'yourselves', "doesn't", 'both', 'that', 'more', 'were', 'are', 'didn', 'has', 'wouldn', 'isn', 'ours', 'now', 'we', "won't", 'being', 'which', 're', 'i', 'with', "shouldn't", 'until', 'been', 'will', "weren't", 'did', 'itself', 'yours', 'then', 'below', 'theirs', 'but', 'if', 'be', 'any', 'weren', 'between', 'during', 'very', 'does', "you'll", "hadn't"}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\himav\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Function to remove stop words

# %%
# Removing the stop words using a function remove_stop()
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

#Just testing it
cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %% [markdown]
# ## Let's make a "pipeline"

# %%
# Making a Pipeline
pipeline = [str.lower, tokenize, remove_stop]
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %% [markdown]
# ## Run the pipeline

# %%
# Running a pipeline
df['tokens'] = df['Description'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# ## Count the tokens

# %%
# Counting the number of tokens using length method
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#                               Title  Rating    Votes     Gross  \
# 80                    Kung Fu Panda     7.6  463,897  $215.43M
# 81                            Mulan     7.6  284,542  $120.62M
# 82               The Little Mermaid     7.6  260,026  $111.54M
# 83                  The Jungle Book     7.6  181,528  $141.84M
# 84  Snow White and the Seven Dwarfs     7.6  197,860  $184.93M
#
#                  Genre  Metascore Certificate             Director  Year  \
# 80   ACTION, ADVENTURE       74.0           U         MARK OSBORNE  2008
# 81   ADVENTURE, COMEDY       71.0           U        TONY BANCROFT  1998
# 82   ADVENTURE, COMEDY       88.0           U         RON CLEMENTS  1989
# 83   ADVENTURE, COMEDY       65.0           U  WOLFGANG REITHERMAN  1967
# 84   ADVENTURE, FAMILY       95.0           U     WILLIAM COTTRELL  1937
#
#                                           Description Runtime  length  \
# 80  ["\NTO EVERYONE'S SURPRISE, INCLUDING HIS OWN,...  92 min     206
# 81  ["\NTO SAVE HER FATHER FROM DEATH IN THE ARMY,...  88 min     151
# 82  ["\NA MERMAID PRINCESS MAKES A FAUSTIAN BARGAI...  83 min     104
# 83  ['\NBAGHEERA THE PANTHER AND BALOO THE BEAR HA...  78 min     136
# 84  ['\NEXILED INTO THE DANGEROUS FOREST BY HER WI...  83 min     146
#
#                                                tokens  num_tokens
# 80  [nto, everyone, surprise, including, po, overw...          18
# 81  [nto, save, father, death, army, young, maiden...          16
# 82  [na, mermaid, princess, makes, faustian, barga...          12
# 83  [nbagheera, panther, baloo, bear, difficult, t...          13
# 84  [nexiled, dangerous, forest, wicked, stepmothe...          13

# %% [markdown]
# ## Use the "Counter"

# %%
# Using the Counter method
from collections import Counter

tokens = tokenize("She likes my cats and my cats like my sofa.")
testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %% [markdown]
# ## Add new data to the current count

# %%
# Adding the new data to the current count
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %% [markdown]
# ## Let's count

# %%
# Counting the most common 5 tokens using map() method
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('na', 34), ('young', 25), ('girl', 15), ('world', 13), ('boy', 12)]

# %% [markdown]
# ## put the word frequency in it's own dataframe for analysis

# %%
# put the word frequency in it’s own dataframe for analysis
freq_df = pd.DataFrame.from_dict(counter,orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %% [markdown]
# ## Sort and display!

# %%
# Sorting and Displaying 10 values of the frequency dataframe
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#         freq
# token
# na        34
# young     25
# girl      15
# world     13
# boy       12
# new       12
# must       9
# nwhen      9
# family     8
# find       7

# %% [markdown]
# ## Stats!

# %%
# Describing the data of the frequency dataframe
freq_df.describe()
# Out:
#              freq
# count  953.000000
# mean     1.432319
# std      1.756705
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max     34.000000

# %% [markdown]
# ## Bar chart

# %%
# plotting top 15 frequency dataframe names in the Y-axis named Token
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()

# Taking X-axis as 'Frequency', Y-axis as 'Token' and title as 'Top Words'
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# ## Pip Installation

# %%
# Installing wordcloud
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\himav\.anaconda\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\himav\.anaconda\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\himav\.anaconda\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\himav\.anaconda\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\himav\.anaconda\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\himav\.anaconda\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\himav\.anaconda\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\himav\.anaconda\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\himav\.anaconda\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\himav\.anaconda\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\himav\.anaconda\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\himav\.anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# ## Word Cloud

# %%
# Importing libraries wordcloud and matplotlib
from wordcloud import WordCloud
from matplotlib import pyplot as plt

# Printing output with the needy requirements
text = df.query("Year==2008 and Certificate == 'U'")['Description'].values[0]
plt.figure(figsize=(14, 7)) ###
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ## All Data Word Cloud

# %%
# Printing output with the needy requirements
wc = WordCloud(background_color='white', width = 300, height=300,max_words=100, margin=2)
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
